# %%
import urllib3
import json

# %%
URL = "http://aiopen.etri.re.kr:8000/WiseNLU"
ACCESSKEY = "4ee51c5e-7d13-4f91-9516-5f68c4fe26f3"
CODE = "dparse"
with open('wiki.txt', 'r') as f:
    text = f.read()
    
len(text)
# Out:
# 9901

# %%
def morp_parsing(text):
    requestJson = {
    "access_key" : ACCESSKEY,
    'argument' : {
        "text" : text,
        "analysis_code" : CODE
        }
    }
    http = urllib3.PoolManager()
    response = http.request("POST", URL, headers={
    "Content-Type":"application/json; charset=UTF-8"
}, body = json.dumps(requestJson))

    a = json.loads(str(response.data, "utf-8"))['return_object']['sentence'][1]['morp']
    print(a)

# %%
# %%time
morp_parsing(text)
# Out:
# [{'id': 0.0, 'lemma': '위키백', 'type': 'NNP', 'position': 16.0, 'weight': 0.6}, {'id': 1.0, 'lemma': '과', 'type': 'JKB', 'position': 25.0, 'weight': 0.0270179}, {'id': 2.0, 'lemma': '는', 'type': 'JX', 'position': 28.0, 'weight': 0.0387928}, {'id': 3.0, 'lemma': '2001', 'type': 'SN', 'position': 32.0, 'weight': 1.0}, {'id': 4.0, 'lemma': '년', 'type': 'NNB', 'position': 36.0, 'weight': 0.414343}, {'id': 5.0, 'lemma': '1', 'type': 'SN', 'position': 40.0, 'weight': 1.0}, {'id': 6.0, 'lemma': '월', 'type': 'NNB', 'position': 41.0, 'weight': 0.408539}, {'id': 7.0, 'lemma': '15', 'type': 'SN', 'position': 45.0, 'weight': 1.0}, {'id': 8.0, 'lemma': '일', 'type': 'NNB', 'position': 47.0, 'weight': 0.126777}, {'id': 9.0, 'lemma': '서비스', 'type': 'NNG', 'position': 51.0, 'weight': 0.9}, {'id': 10.0, 'lemma': '를', 'type': 'JKO', 'position': 60.0, 'weight': 0.137686}, {'id': 11.0, 'lemma': '개시', 'type': 'NNG', 'position': 64.0, 'weight': 0.9}, {'id': 12.0, 'lemma': '하', 'type': 'XSV', 'position': 70.0, 'weight': 0.0001}, {'id': 13.0, 'lemma': '었', 'type': 'EP', 'position': 73.0, 'weight': 0.9}, {'id': 14.0, 'lemma': '다', 'type': 'EF', 'position': 76.0, 'weight': 0.640954}, {'id': 15.0, 'lemma': '.', 'type': 'SF', 'position': 79.0, 'weight': 1.0}]
# CPU times: user 116 ms, sys: 16 ms, total: 132 ms
# Wall time: 3.02 s

# %%
from konlpy.tag import Twitter, Kkma, Mecab, Hannanum, Komoran

# %%
twitter = Twitter()
kkma = Kkma()
hana = Hannanum()
komo = Komoran()
# Out:
# /home/ubuntu/anaconda3/envs/juns/lib/python3.6/site-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# ---------------------------------------------------------------------------
# java.lang.OutOfMemoryError                Traceback (most recent call last)
# <ipython-input-112-faecabec693b> in <module>
#       2 kkma = Kkma()
#       3 hana = Hannanum()
# ----> 4 komo = Komoran()
#
# ~/anaconda3/envs/juns/lib/python3.6/site-packages/konlpy/tag/_komoran.py in __init__(self, jvmpath, userdic, modelpath, max_heap_size)
#     102
#     103         try:
# --> 104             self.jki = komoranJavaPackage.Komoran(self.modelpath)
#     105         except TypeError:  # Package kr.lucypark.komoran.KomoranInterface is not Callable
#     106             raise IOError("Cannot access komoran-dic. Please leave an issue at https://github.com/konlpy/konlpy/issues")
#
# ~/anaconda3/envs/juns/lib/python3.6/site-packages/jpype/_jobject.py in __init__(self, *args)
#      93             object.__setattr__(self, '__javavalue__', args[0])
#      94         elif not hasattr(self, '__javavalue__'):
# ---> 95             jv = self.__class__.__javaclass__.newInstance(*args)
#      96             object.__setattr__(self, '__javavalue__', jv)
#      97         super(JObject, self).__init__()
#
# java.lang.OutOfMemoryError: GC overhead limit exceeded

# %%
# %%time
a = twitter.pos(text)
# Out:
# CPU times: user 10.5 s, sys: 0 ns, total: 10.5 s
# Wall time: 1.17 s

# %%
# %%time
b = kkma.pos(text, flatten=False)
# Out:
# CPU times: user 2min 40s, sys: 0 ns, total: 2min 40s
# Wall time: 15.8 s

# %%
# %%time
c = kkma.pos(text)
# Out:
# CPU times: user 2min 57s, sys: 0 ns, total: 2min 57s
# Wall time: 17 s

# %%
# %%time
d = hana.pos(text)
# Out:
# CPU times: user 8.37 s, sys: 0 ns, total: 8.37 s
# Wall time: 858 ms

# %%
# %%time
komo_data = komo.pos(" ")
# Out:
# ---------------------------------------------------------------------------
# java.lang.NullPointerException            Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/anaconda3/envs/juns/lib/python3.6/site-packages/konlpy/tag/_komoran.py in pos(self, phrase, flatten, join)
#      64
#      65         for sentence in sentences:
# ---> 66             result = self.jki.analyze(sentence).getTokenList()
#      67             result = [(token.getMorph(), token.getPos()) for token in result]
#      68
#
# java.lang.NullPointerException: None

# %%
d
# Out:
# [('출범', 'N'),
#  ('과', 'J'),
#  ('성장', 'N'),
#  ('위키백', 'N'),
#  ('과는', 'J'),
#  ('2001년', 'N'),
#  ('1월', 'N'),
#  ('15', 'N'),
#  ('이', 'J'),
#  ('ㄹ', 'E'),
#  ('서비스', 'N'),
#  ('를', 'J'),
#  ('개시', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('도메인', 'N'),
#  ('은', 'J'),
#  ('www', 'F'),
#  ('.', 'S'),
#  ('wikipedia', 'F'),
#  ('.', 'S'),
#  ('com', 'F'),
#  ('을', 'J'),
#  ('사용', 'N'),
#  ('하', 'X'),
#  ('었고', 'E'),
#  ('사용', 'N'),
#  ('언어', 'N'),
#  ('는', 'J'),
#  ('영어', 'N'),
#  ('하나', 'N'),
#  ('뿐', 'X'),
#  ('이', 'J'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('12', 'N'),
#  (']', 'S'),
#  ('래리', 'N'),
#  ('생어', 'N'),
#  ('는', 'J'),
#  ('위키백과', 'N'),
#  ('의', 'J'),
#  ('출범', 'N'),
#  ('소식', 'N'),
#  ('역시', 'M'),
#  ('누피디', 'N'),
#  ('이', 'J'),
#  ('어', 'E'),
#  ('메일링', 'N'),
#  ('리스트', 'N'),
#  ('를', 'J'),
#  ('통하', 'P'),
#  ('어', 'E'),
#  ('알리', 'P'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('8', 'N'),
#  (']', 'S'),
#  ('위키백과', 'N'),
#  ('가', 'J'),
#  ('시작', 'N'),
#  ('되', 'X'),
#  ('ㄴ', 'E'),
#  ('지', 'N'),
#  ('하', 'P'),
#  ('ㄴ', 'E'),
#  ('달', 'N'),
#  ('안', 'N'),
#  ('에', 'J'),
#  ('중립성', 'N'),
#  ('정책', 'N'),
#  ('이', 'J'),
#  ('수립', 'N'),
#  ('되', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('13', 'N'),
#  (']', 'S'),
#  ('이후', 'N'),
#  ('몇', 'N'),
#  ('가지', 'N'),
#  ('정책', 'N'),
#  ('이', 'J'),
#  ('수립', 'N'),
#  ('되', 'X'),
#  ('면서', 'E'),
#  ('위키백', 'N'),
#  ('과는', 'J'),
#  ('누피디아', 'N'),
#  ('와는', 'J'),
#  ('별개', 'N'),
#  ('이', 'J'),
#  ('ㄴ', 'E'),
#  ('서비스', 'N'),
#  ('가', 'J'),
#  ('되', 'P'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('8', 'N'),
#  (']', 'S'),
#  ('애초', 'N'),
#  ('에', 'J'),
#  ('보미스', 'N'),
#  ('는', 'J'),
#  ('위키백과', 'N'),
#  ('를', 'J'),
#  ('영리', 'N'),
#  ('목적', 'N'),
#  ('으로', 'J'),
#  ('운영', 'N'),
#  ('하', 'X'),
#  ('려고', 'E'),
#  ('하', 'P'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('14', 'N'),
#  (']', 'S'),
#  ('위키백과', 'N'),
#  ('의', 'J'),
#  ('초', 'N'),
#  ('이', 'J'),
#  ('기', 'E'),
#  ('편집자들', 'N'),
#  ('은', 'J'),
#  ('누피디아,', 'N'),
#  ('슬래시닷,', 'N'),
#  ('그리고', 'M'),
#  ('웹', 'N'),
#  ('검색', 'N'),
#  ('엔진', 'N'),
#  ('을', 'J'),
#  ('통하', 'P'),
#  ('어', 'E'),
#  ('유입', 'N'),
#  ('되', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('2001년', 'N'),
#  ('8월', 'N'),
#  ('8일', 'N'),
#  ('위키백과', 'N'),
#  ('의', 'J'),
#  ('문서수', 'N'),
#  ('는', 'J'),
#  ('약', 'N'),
#  ('8,000', 'N'),
#  ('개', 'N'),
#  ('가', 'J'),
#  ('되', 'P'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('15', 'N'),
#  (']', 'S'),
#  ('2001년', 'N'),
#  ('말', 'N'),
#  ('이', 'J'),
#  ('되', 'P'),
#  ('자', 'E'),
#  ('위키백', 'N'),
#  ('과는', 'J'),
#  ('18개', 'N'),
#  ('언어판', 'N'),
#  ('으로', 'J'),
#  ('늘', 'P'),
#  ('었고', 'E'),
#  (',', 'S'),
#  ('문', 'N'),
#  ('서', 'J'),
#  ('수', 'N'),
#  ('는', 'J'),
#  ('2만여', 'N'),
#  ('개', 'N'),
#  ('까지', 'J'),
#  ('늘', 'P'),
#  ('어', 'E'),
#  ('나', 'P'),
#  ('아다', 'E'),
#  ('.', 'S'),
#  ('위키백과', 'N'),
#  ('를', 'J'),
#  ('서비스', 'N'),
#  ('하', 'P'),
#  ('는', 'E'),
#  ('언어', 'N'),
#  ('는', 'J'),
#  ('2002년', 'N'),
#  ('말', 'N'),
#  ('에는', 'J'),
#  ('26개', 'N'),
#  (',', 'S'),
#  ('2003년', 'N'),
#  ('말', 'N'),
#  ('에는', 'J'),
#  ('46개', 'N'),
#  (',', 'S'),
#  ('2004년', 'N'),
#  ('말', 'N'),
#  ('에는', 'J'),
#  ('161개', 'N'),
#  ('로', 'J'),
#  ('늘', 'P'),
#  ('어', 'E'),
#  ('나', 'P'),
#  ('아다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('16', 'N'),
#  (']', 'S'),
#  ('누피디아', 'N'),
#  ('는', 'J'),
#  ('위키백과', 'N'),
#  ('와', 'J'),
#  ('병립', 'N'),
#  ('하', 'X'),
#  ('어', 'E'),
#  ('운영', 'N'),
#  ('되', 'X'),
#  ('다가', 'E'),
#  ('컨텐츠', 'N'),
#  ('를', 'J'),
#  ('위키백과', 'N'),
#  ('로', 'J'),
#  ('넘', 'P'),
#  ('기', 'E'),
#  ('이', 'J'),
#  ('고', 'E'),
#  ('2003년', 'N'),
#  ('서버', 'N'),
#  ('를', 'J'),
#  ('다운', 'N'),
#  ('시키', 'X'),
#  ('어', 'E'),
#  ('마감', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('2002년', 'N'),
#  ('사용자', 'N'),
#  ('사이', 'N'),
#  ('에서', 'J'),
#  ('위키백과', 'N'),
#  ('의', 'J'),
#  ('광고', 'N'),
#  ('수줍', 'P'),
#  ('어', 'E'),
#  ('그', 'N'),
#  ('에', 'J'),
#  ('따르', 'P'),
#  ('ㄴ', 'E'),
#  ('상업적', 'N'),
#  ('운용', 'N'),
#  ('에', 'J'),
#  ('대하', 'P'),
#  ('ㄴ', 'E'),
#  ('우려', 'N'),
#  ('가', 'J'),
#  ('크', 'P'),
#  ('어', 'E'),
#  ('지', 'P'),
#  ('었고', 'E'),
#  (',', 'S'),
#  ('이', 'N'),
#  ('에', 'J'),
#  ('따르', 'P'),
#  ('아', 'E'),
#  ('스페인어', 'N'),
#  ('위키백', 'N'),
#  ('과', 'J'),
#  ('사용자들', 'N'),
#  ('은', 'J'),
#  ('위키백', 'N'),
#  ('과', 'J'),
#  ('소스', 'N'),
#  ('를', 'J'),
#  ('포크하', 'N'),
#  ('이', 'J'),
#  ('어', 'E'),
#  ('별도', 'N'),
#  ('의', 'J'),
#  ('위키백과', 'N'),
#  ('이', 'J'),
#  ('ㄴ', 'E'),
#  ('엔시클로페디아', 'N'),
#  ('리브레(Enciclopedia', 'N'),
#  ('Libre', 'F'),
#  ('Universal', 'F'),
#  ('en', 'F'),
#  ('Español)', 'N'),
#  ('를', 'J'),
#  ('개설', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('17', 'N'),
#  (']', 'S'),
#  ('이', 'N'),
#  ('에', 'J'),
#  ('자극', 'N'),
#  ('받', 'X'),
#  ('은', 'E'),
#  ('지미', 'N'),
#  ('웨일스', 'N'),
#  ('는', 'J'),
#  ('위키백과', 'N'),
#  ('에', 'J'),
#  ('광고', 'N'),
#  ('를', 'J'),
#  ('도입', 'N'),
#  ('하', 'X'),
#  ('지', 'E'),
#  ('않', 'P'),
#  ('겠다', 'E'),
#  ('고', 'J'),
#  ('선언', 'N'),
#  ('하', 'X'),
#  ('었고', 'E'),
#  ('도메인', 'N'),
#  ('을', 'J'),
#  ('wikipedia', 'F'),
#  ('.', 'S'),
#  ('com', 'F'),
#  ('에서', 'J'),
#  ('wikipedia', 'F'),
#  ('.', 'S'),
#  ('org', 'F'),
#  ('로', 'J'),
#  ('변경', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('18', 'N'),
#  (']', 'S'),
#  ('영어', 'N'),
#  ('위키백과', 'N'),
#  ('의', 'J'),
#  ('증대', 'N'),
#  ('속', 'N'),
#  ('도는', 'J'),
#  ('2007년', 'N'),
#  ('초', 'N'),
#  ('정점', 'N'),
#  ('을', 'J'),
#  ('찍', 'P'),
#  ('었고', 'E'),
#  (',', 'S'),
#  ('2009년', 'N'),
#  ('8월', 'N'),
#  ('3백', 'N'),
#  ('만', 'J'),
#  ('문서', 'N'),
#  ('를', 'J'),
#  ('넘기', 'P'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('19', 'N'),
#  (']', 'S'),
#  ('위키백', 'N'),
#  ('과', 'J'),
#  ('전체', 'N'),
#  ('의', 'J'),
#  ('문서수', 'N'),
#  ('는', 'J'),
#  ('2006년', 'N'),
#  ('가장', 'M'),
#  ('빠르', 'P'),
#  ('게', 'E'),
#  ('늘', 'P'),
#  ('어', 'E'),
#  ('매일', 'M'),
#  ('약', 'N'),
#  ('1,800', 'N'),
#  ('개', 'N'),
#  ('의', 'J'),
#  ('문서', 'N'),
#  ('가', 'J'),
#  ('새로', 'M'),
#  ('생기', 'P'),
#  ('어', 'E'),
#  ('나', 'P'),
#  ('아다', 'E'),
#  ('.', 'S'),
#  ('그', 'M'),
#  ('뒤', 'N'),
#  ('로', 'J'),
#  ('문', 'N'),
#  ('서', 'J'),
#  ('증', 'N'),
#  ('가', 'J'),
#  ('속', 'N'),
#  ('도는', 'J'),
#  ('둔화', 'N'),
#  ('되', 'X'),
#  ('어', 'E'),
#  ('2013년', 'N'),
#  ('의', 'J'),
#  ('경우', 'N'),
#  ('연평균', 'N'),
#  ('으로', 'J'),
#  ('보', 'P'),
#  ('아ㄹ', 'E'),
#  ('때', 'N'),
#  ('매일', 'M'),
#  ('약', 'N'),
#  ('800개', 'N'),
#  ('의', 'J'),
#  ('문서', 'N'),
#  ('가', 'J'),
#  ('새로', 'M'),
#  ('생기', 'P'),
#  ('어', 'E'),
#  ('나', 'P'),
#  ('아다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('20', 'N'),
#  (']', 'S'),
#  ('위키백과', 'N'),
#  ('의', 'J'),
#  ('성장', 'N'),
#  ('둔화', 'N'),
#  ('원인', 'N'),
#  ('에', 'J'),
#  ('대', 'P'),
#  ('어', 'E'),
#  ('하', 'P'),
#  ('어', 'E'),
#  ('팰로앨토', 'N'),
#  ('연구소', 'N'),
#  ('는', 'J'),
#  ('프로젝트', 'N'),
#  ('의', 'J'),
#  ('품질', 'N'),
#  ('이', 'J'),
#  ('고급화', 'N'),
#  ('되', 'P'),
#  ('면서', 'E'),
#  ('변화', 'N'),
#  ('에', 'J'),
#  ('대하', 'P'),
#  ('ㄴ', 'E'),
#  ('저항', 'N'),
#  ('이', 'J'),
#  ('있', 'P'),
#  ('다', 'E'),
#  ('고', 'J'),
#  ('분석', 'N'),
#  ('하', 'X'),
#  ('ㄴ', 'E'),
#  ('바', 'N'),
#  ('있', 'P'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('21', 'N'),
#  (']', 'S'),
#  ('성장', 'N'),
#  ('둔화', 'N'),
#  ('에', 'J'),
#  ('대하', 'P'),
#  ('ㄴ', 'E'),
#  ('다른', 'M'),
#  ('분석', 'N'),
#  ('으로는', 'J'),
#  ('"', 'S'),
#  ('낮', 'N'),
#  ('은', 'J'),
#  ('가지', 'N'),
#  ('에', 'J'),
#  ('달리', 'P'),
#  ('ㄴ', 'E'),
#  ('열매', 'N'),
#  ('"', 'S'),
#  ('처럼', 'J'),
#  ('주제', 'N'),
#  ('나', 'J'),
#  ('가치', 'N'),
#  ('가', 'J'),
#  ('분명', 'N'),
#  ('하', 'X'),
#  ('어', 'E'),
#  ('쉽', 'P'),
#  ('게', 'E'),
#  ('만들', 'P'),
#  ('ㄹ', 'E'),
#  ('수', 'N'),
#  ('있', 'P'),
#  ('는', 'E'),
#  ('문', 'N'),
#  ('서는', 'J'),
#  ('이미', 'M'),
#  ('다', 'M'),
#  ('만들', 'P'),
#  ('어', 'E'),
#  ('지', 'P'),
#  ('었기', 'E'),
#  ('때문', 'N'),
#  ('이', 'J'),
#  ('라는', 'E'),
#  ('설명', 'N'),
#  ('이', 'J'),
#  ('있', 'P'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('22', 'N'),
#  ('][', 'S'),
#  ('23', 'N'),
#  ('][', 'S'),
#  ('24', 'N'),
#  (']', 'S'),
#  ('2009년', 'N'),
#  ('11월', 'N'),
#  ('스페', 'N'),
#  ('이', 'J'),
#  ('ㄴ', 'E'),
#  ('마드리드', 'N'),
#  ('의', 'J'),
#  ('후', 'N'),
#  ('안', 'X'),
#  ('카를로스', 'N'),
#  ('국왕', 'N'),
#  ('대학교', 'N'),
#  ('의', 'J'),
#  ('연구자', 'N'),
#  ('는', 'J'),
#  ('2009년', 'N'),
#  ('1분기', 'N'),
#  ('동안', 'N'),
#  ('영어', 'N'),
#  ('위키백과', 'N'),
#  ('가', 'J'),
#  ('49,000', 'N'),
#  ('여명', 'N'),
#  ('의', 'J'),
#  ('기여자', 'N'),
#  ('를', 'J'),
#  ('잃', 'P'),
#  ('었다는', 'E'),
#  ('분석', 'N'),
#  ('을', 'J'),
#  ('내', 'P'),
#  ('어', 'E'),
#  ('놓', 'P'),
#  ('아다', 'E'),
#  ('.', 'S'),
#  ('2008년', 'N'),
#  ('의', 'J'),
#  ('같', 'P'),
#  ('은', 'E'),
#  ('기간', 'N'),
#  ('에', 'J'),
#  ('줄어들', 'P'),
#  ('ㄴ', 'E'),
#  ('기여', 'N'),
#  ('이', 'J'),
#  ('자', 'E'),
#  ('수', 'N'),
#  ('가', 'J'),
#  ('4,900', 'N'),
#  ('여명', 'N'),
#  ('이', 'J'),
#  ('었던', 'E'),
#  ('것', 'N'),
#  ('에', 'J'),
#  ('비하', 'P'),
#  ('어', 'E'),
#  ('열', 'P'),
#  ('ㄹ', 'E'),
#  ('배', 'N'),
#  ('이', 'J'),
#  ('나', 'E'),
#  ('더', 'M'),
#  ('많', 'P'),
#  ('은', 'E'),
#  ('수치', 'N'),
#  ('이', 'J'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('25', 'N'),
#  ('][', 'S'),
#  ('26', 'N'),
#  (']', 'S'),
#  ('《월스트리트', 'N'),
#  ('저널》', 'N'),
#  ('은', 'J'),
#  ('까다롭', 'P'),
#  ('어', 'E'),
#  ('지', 'P'),
#  ('ㄴ', 'E'),
#  ('편집', 'N'),
#  ('지침', 'N'),
#  ('의', 'J'),
#  ('증가', 'N'),
#  ('가', 'J'),
#  ('이러하', 'P'),
#  ('ㄴ', 'E'),
#  ('경향', 'N'),
#  ('을', 'J'),
#  ('이끌', 'P'),
#  ('었다', 'E'),
#  ('고', 'J'),
#  ('보도', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('27', 'N'),
#  (']', 'S'),
#  ('지미', 'N'),
#  ('웨일스', 'N'),
#  ('는', 'J'),
#  ('이러하', 'P'),
#  ('ㄴ', 'E'),
#  ('연구가', 'N'),
#  ('잘못된', 'N'),
#  ('방법론', 'N'),
#  ('에', 'J'),
#  ('의하', 'P'),
#  ('ㄴ', 'E'),
#  ('것', 'N'),
#  ('이', 'J'),
#  ('라며', 'E'),
#  ('분석', 'N'),
#  ('결과', 'N'),
#  ('를', 'J'),
#  ('거부', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('28', 'N'),
#  (']', 'S'),
#  ('2년', 'N'),
#  ('뒤', 'N'),
#  ('이', 'J'),
#  ('ㄴ', 'E'),
#  ('2011년', 'N'),
#  ('지미', 'N'),
#  ('웨일스', 'N'),
#  ('는', 'J'),
#  ('하', 'P'),
#  ('ㄴ', 'E'),
#  ('인터뷰', 'N'),
#  ('에서', 'J'),
#  ('기여', 'N'),
#  ('이', 'J'),
#  ('자', 'E'),
#  ('감소', 'N'),
#  ('를', 'J'),
#  ('인정', 'N'),
#  ('하', 'X'),
#  ('었지만', 'E'),
#  (',', 'S'),
#  ('2010년', 'N'),
#  ('6월', 'N'),
#  ('의', 'J'),
#  ('"', 'S'),
#  ('최소', 'N'),
#  ('36,000', 'N'),
#  ('명', 'N'),
#  ('의', 'J'),
#  ('편집자', 'N'),
#  ('"', 'S'),
#  ('에서', 'J'),
#  ('2011년', 'N'),
#  ('6월', 'N'),
#  ('당시', 'N'),
#  ('의', 'J'),
#  ('35,800', 'N'),
#  ('명', 'N'),
#  ('의', 'J'),
#  ('편집자', 'N'),
#  ('사이', 'N'),
#  ('의', 'J'),
#  ('격차', 'N'),
#  ('는', 'J'),
#  ('그리', 'M'),
#  ('크', 'P'),
#  ('지', 'E'),
#  ('않', 'P'),
#  ('다', 'E'),
#  ('고', 'J'),
#  ('주장', 'N'),
#  ('하', 'X'),
#  ('면서', 'E'),
#  ('위키백', 'N'),
#  ('과', 'J'),
#  ('편집자', 'N'),
#  ('의', 'J'),
#  ('수', 'N'),
#  ('는', 'J'),
#  ('"', 'S'),
#  ('안정적', 'N'),
#  ('이', 'J'),
#  ('고', 'E'),
#  ('지속', 'N'),
#  ('적', 'X'),
#  ('"', 'S'),
#  ('이', 'N'),
#  ('이', 'J'),
#  ('라', 'E'),
#  ('고', 'J'),
#  ('말', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('29', 'N'),
#  (']', 'S'),
#  ('2013년', 'N'),
#  ('매사추세츠', 'N'),
#  ('공과대학교', 'N'),
#  ('의', 'J'),
#  ('《테크놀로지', 'N'),
#  ('리뷰》', 'N'),
#  ('에', 'J'),
#  ('실리', 'P'),
#  ('ㄴ', 'E'),
#  ('〈위키백과', 'N'),
#  ('의', 'J'),
#  ('하락〉(The', 'N'),
#  ('Decline', 'F'),
#  ('of', 'F'),
#  ('Wikipedia', 'F'),
#  (')', 'S'),
#  ('은', 'J'),
#  ('지미', 'N'),
#  ('웨일스', 'N'),
#  ('의', 'J'),
#  ('이러하', 'P'),
#  ('ㄴ', 'E'),
#  ('주장', 'N'),
#  ('을', 'J'),
#  ('반박', 'N'),
#  ('하고', 'J'),
#  ('있', 'P'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('이', 'M'),
#  ('글', 'N'),
#  ('의', 'J'),
#  ('분석', 'N'),
#  ('에', 'J'),
#  ('따르', 'P'),
#  ('면', 'E'),
#  ('위키백', 'N'),
#  ('과는', 'J'),
#  ('2007년', 'N'),
#  ('이후', 'N'),
#  ('위키백', 'N'),
#  ('과', 'J'),
#  ('문서', 'N'),
#  ('를', 'J'),
#  ('업데이트하', 'N'),
#  ('이', 'J'),
#  ('고', 'E'),
#  ('교정', 'N'),
#  ('하', 'X'),
#  ('던', 'E'),
#  ('자원', 'N'),
#  ('편집자', 'N'),
#  ('가운데', 'N'),
#  ('3분', 'N'),
#  ('의', 'J'),
#  ('1', 'N'),
#  ('을', 'J'),
#  ('잃', 'P'),
#  ('었으며', 'E'),
#  (',', 'S'),
#  ('편집자', 'N'),
#  ('의', 'J'),
#  ('상당수', 'N'),
#  ('는', 'J'),
#  ('사소', 'N'),
#  ('하', 'X'),
#  ('ㄴ', 'E'),
#  ('편집만', 'N'),
#  ('을', 'J'),
#  ('하', 'P'),
#  ('는', 'E'),
#  ('것', 'N'),
#  ('으로', 'J'),
#  ('나타나', 'P'),
#  ('아다', 'E'),
#  ('.', 'S'),
#  ('[30]《디', 'N'),
#  ('애틀랜틱》', 'N'),
#  ('2012년', 'N'),
#  ('7월호', 'N'),
#  ('는', 'J'),
#  ('관리자', 'N'),
#  ('의', 'J'),
#  ('수', 'N'),
#  ('역시', 'M'),
#  ('줄어들', 'P'),
#  ('었다', 'E'),
#  ('고', 'J'),
#  ('보도', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('31', 'N'),
#  (']', 'S'),
#  ('2013년', 'N'),
#  ('11월', 'N'),
#  ('25일', 'N'),
#  ('《뉴욕》', 'N'),
#  ('의', 'J'),
#  ('크', 'P'),
#  ('어서리ㄴ', 'E'),
#  ('워드', 'N'),
#  ('는', 'J'),
#  ('“여섯', 'N'),
#  ('번', 'N'),
#  ('째', 'X'),
#  ('로', 'J'),
#  ('많', 'P'),
#  ('이', 'X'),
#  ('사용', 'N'),
#  ('되', 'X'),
#  ('는', 'E'),
#  ('웹싸이트', 'N'),
#  ('이', 'J'),
#  ('ㄴ', 'E'),
#  ('위키백과', 'N'),
#  ('가', 'J'),
#  ('내부', 'N'),
#  ('비판', 'N'),
#  ('에', 'J'),
#  ('휩싸였다”', 'N'),
#  ('는', 'J'),
#  ('기사', 'N'),
#  ('를', 'J'),
#  ('내보내', 'P'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('32', 'N'),
#  (']', 'S'),
#  ('주요', 'N'),
#  ('이력', 'N'),
#  ('위키백', 'N'),
#  ('과', 'J'),
#  ('문', 'N'),
#  ('서', 'J'),
#  ('수(모든', 'N'),
#  ('언어', 'N'),
#  (')[', 'S'),
#  ('33', 'N'),
#  (']', 'S'),
#  ('월', 'N'),
#  ('100회', 'N'),
#  ('이상', 'N'),
#  ('편집', 'N'),
#  ('하', 'X'),
#  ('ㄴ', 'E'),
#  ('위키백', 'N'),
#  ('과', 'J'),
#  ('사용자', 'N'),
#  ('수(모든', 'N'),
#  ('언어', 'N'),
#  (')[', 'S'),
#  ('34', 'N'),
#  (']', 'S'),
#  ('2007년', 'N'),
#  ('1월', 'N'),
#  ('위키백', 'N'),
#  ('과는', 'J'),
#  ('처음', 'N'),
#  ('으로', 'J'),
#  ('가장', 'M'),
#  ('인기', 'N'),
#  ('있', 'X'),
#  ('는', 'E'),
#  ('웹사이트', 'N'),
#  ('리스트', 'N'),
#  ('톱', 'N'),
#  ('10', 'N'),
#  ('에', 'J'),
#  ('이름', 'N'),
#  ('을', 'J'),
#  ('올리', 'P'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('컴스코어', 'N'),
#  ('는', 'J'),
#  ('위키백과', 'N'),
#  ('의', 'J'),
#  ('연간', 'N'),
#  ('방문자', 'N'),
#  ('를', 'J'),
#  ('4,290', 'N'),
#  ('만', 'J'),
#  ('명', 'N'),
#  ('으로', 'J'),
#  ('집계', 'N'),
#  ('하', 'X'),
#  ('며', 'E'),
#  ('9위', 'N'),
#  ('로', 'J'),
#  ('올리', 'P'),
#  ('었고', 'E'),
#  (',', 'S'),
#  ('《뉴욕타임즈》', 'N'),
#  ('는', 'J'),
#  ('10', 'N'),
#  ('로', 'J'),
#  ('올리', 'P'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('애플', 'N'),
#  ('은', 'J'),
#  ('11위', 'N'),
#  ('로', 'J'),
#  ('집계', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('2006년도', 'N'),
#  ('의', 'J'),
#  ('순위', 'N'),
#  ('가', 'J'),
#  ('33위', 'N'),
#  ('이', 'J'),
#  ('었던', 'E'),
#  ('것', 'N'),
#  ('에', 'J'),
#  ('비하', 'P'),
#  ('면', 'E'),
#  ('놀랍', 'P'),
#  ('은', 'E'),
#  ('부상', 'N'),
#  ('이', 'J'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('35', 'N'),
#  (']', 'S'),
#  ('2015년', 'N'),
#  ('3월', 'N'),
#  ('위키백', 'N'),
#  ('과는', 'J'),
#  ('5위', 'N'),
#  ('를', 'J'),
#  ('기록', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('36', 'N'),
#  ('][', 'S'),
#  ('37', 'N'),
#  (']', 'S'),
#  ('이', 'M'),
#  ('시', 'N'),
#  ('이', 'J'),
#  ('기', 'E'),
#  ('순위', 'N'),
#  ('는', 'J'),
#  ('알렉사', 'N'),
#  ('인터넷', 'N'),
#  ('의', 'J'),
#  ('조사', 'N'),
#  ('에', 'J'),
#  ('의하', 'P'),
#  ('ㄴ', 'E'),
#  ('것', 'N'),
#  ('으로', 'J'),
#  (',', 'S'),
#  ('위키백', 'N'),
#  ('과는', 'J'),
#  ('2014년', 'N'),
#  ('내', 'P'),
#  ('어', 'E'),
#  ('내', 'P'),
#  ('어', 'E'),
#  ('매', 'P'),
#  ('어', 'E'),
#  ('월', 'N'),
#  ('8억', 'N'),
#  ('이상', 'N'),
#  ('의', 'J'),
#  ('페이지', 'N'),
#  ('뷰', 'N'),
#  ('를', 'J'),
#  ('기록', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ...]
